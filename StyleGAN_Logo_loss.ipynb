# %%
# !rm -r stylegan2-pytorch
# !git clone https://github.com/ZloyTapok987/stylegan2-pytorch.git
# !pip install ninja
# !./stylegan2-pytorch/logohunter/build/build.sh
# Out:
# rm: cannot remove 'stylegan2-pytorch': No such file or directory
# Cloning into 'stylegan2-pytorch'...
# remote: Enumerating objects: 677, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 677 (delta 127), reused 113 (delta 113), pack-reused 528
# Receiving objects: 100% (677/677), 152.90 MiB | 19.48 MiB/s, done.
# Resolving deltas: 100% (256/256), done.
# ...
#      |████████████████████████████████| 108 kB 12.0 MB/s
# ...
# Hello
# This script will set up the logohunter environment:
#  - downloading pretrained YOLOv3 weights...
# ...
# --2022-04-25 22:41:13--  http://logohunters3.s3-us-west-2.amazonaws.com/yolo_weights_logos.h5
# Resolving logohunters3.s3-us-west-2.amazonaws.com (logohunters3.s3-us-west-2.amazonaws.com)... 52.218.246.201
# Connecting to logohunters3.s3-us-west-2.amazonaws.com (logohunters3.s3-us-west-2.amazonaws.com)|52.218.246.201|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# %cd stylegan2-pytorch/logohunter/src
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()
# !python ../../../stylegan2-pytorch/train.py /content/drive/MyDrive/diploma/LOGOS_PREPARED --size 128 --augment --ckpt /content/drive/MyDrive/diploma/checkpointLOGAN/237000.pt
# Out:
# /content/stylegan2-pytorch/logohunter/src
# 2022-04-25 22:43:24.645835: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# keras_yolo3/yolo_weights_logos.h5 model, anchors, and classes loaded in 9.90sec.
# load model: /content/drive/MyDrive/diploma/checkpointLOGAN/237000.pt
#  30% 237000/800000 [00:00<?, ?it/s]/content/stylegan2-pytorch/op/conv2d_gradfix.py:89: UserWarning: conv2d_gradfix not supported on PyTorch 1.11.0+cu113. Falling back to torch.nn.functional.conv2d().
# ...
